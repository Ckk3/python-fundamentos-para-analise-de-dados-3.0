# %%
import sqlite3
import matplotlib.pyplot as plt

# %%
con = sqlite3.connect('dsa.db')
cursor = con.cursor()

# %%
def plot_data():
    #Get data to plot
    cursor.execute('select id, value from products')
    ids, values = list(), list()
    for row in cursor.fetchall():
        ids.append(row[0])
        values.append(row[1])

    plt.title('Value spend by id')
    plt.bar(x=ids, height=values)
    plt.show()

# %%
plot_data()
